# %%
import pandas as pd

# %%
batman0 = pd.read_csv('batman0.csv')

# %%
batman0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   306 non-null    int64
#  1   aliases                      0 non-null      float64
#  2   api_detail_url               200 non-null    object
#  3   associated_images            200 non-null    object
#  4   character_credits            200 non-null    object
#  5   character_died_in            200 non-null    object
#  6   concept_credits              200 non-null    object
#  7   cover_date                   200 non-null    object
#  8   date_added                   200 non-null    object
#  9   date_last_updated            200 non-null    object
#  10  deck                         3 non-null      object
#  11  description                  181 non-null    object
#  12  first_appearance_characters  0 non-null      float64
# ...

# %%
batman0.isnull().sum()
# Out:
# Unnamed: 0                       0
# aliases                        306
# api_detail_url                 106
# associated_images              106
# character_credits              106
# character_died_in              106
# concept_credits                106
# cover_date                     106
# date_added                     106
# date_last_updated              106
# deck                           303
# description                    125
# first_appearance_characters    306
# first_appearance_concepts      306
# first_appearance_locations     306
# first_appearance_objects       306
# first_appearance_storyarcs     306
# first_appearance_teams         306
# has_staff_review               106
# id                             106
# image                          106
# issue_number                   106
# location_credits               106
# name                           106
# object_credits                 106
# person_credits                 106
# site_detail_url                106
# ...

# %% [markdown]
# There are a lot of null values in all of the columms. I'll have to go through and either fill it out or drop the rows. I'll probably drop them. Gathering this data from the API was much harder than expected. There were a lot of time outs and etc.
#
# Using the API was harder than expected. I've gotten the hang of it now. However, I find that the biggest issue is limited amount of requests I can make. This should be smoother sailing from here. But the limited requests was hell on testing as it limited the amount of times I could try and call the API when I made mistakes.

# %%
batman0.head()
# Out:
#    Unnamed: 0  aliases                                     api_detail_url  \
# 0           0      NaN  https://comicvine.gamespot.com/api/issue/4000-...
# 1           1      NaN  https://comicvine.gamespot.com/api/issue/4000-...
# 2           2      NaN  https://comicvine.gamespot.com/api/issue/4000-...
# 3           3      NaN  https://comicvine.gamespot.com/api/issue/4000-...
# 4           4      NaN  https://comicvine.gamespot.com/api/issue/4000-...
#
#   associated_images                                  character_credits  \
# 0                []  [{'api_detail_url': 'https://comicvine.gamespo...
# 1                []  [{'api_detail_url': 'https://comicvine.gamespo...
# 2                []  [{'api_detail_url': 'https://comicvine.gamespo...
# 3                []  [{'api_detail_url': 'https://comicvine.gamespo...
# 4                []  [{'api_detail_url': 'https://comicvine.gamespo...
#
#   character_died_in                                    concept_credits  \
# ...
